# %% [markdown]
# <a href="https://colab.research.google.com/github/MrEuclid/classroom_tools/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 598-480-679

# %%
n = 703
e = 13
d = 349

# %%
P = ord("P")
C = P**e % n
print(C);
# Out:
# 598

# %%
C = input("Code")
P = int(C)**d % n
print(chr(P))
# Out:
# Code598
# P
