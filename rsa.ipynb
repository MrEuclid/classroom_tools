# %% [markdown]
# <a href="https://colab.research.google.com/github/MrEuclid/classroom_tools/blob/main/rsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 480+357+570+518+218+175+357+598+580+679

# %%
print(chr(73));
# Out:
# I

# %%
N = 703;
e = 13;
d = 349;

# %%
C = input("Code");
P = int(C)**d % N;
print(chr(P));
# Out:
# Code480
# I

# %%
P= ord("I");
C = P**e % N;
print(C);
# Out:
# 480

# %%
P= ord("L");
C = P**e % N;
print(C);
# Out:
# 570

# %%
P= ord("o");
C = P**e % N;
print(C);
# Out:
# 518

# %%
P= ord("v");
C = P**e % N;
print(C);
# Out:
# 218

# %%
P= ord("e");
C = P**e % N;
print(C);
# Out:
# 175

# %%
P= ord(" ");
C = P**e % N;
print(C);
# Out:
# 357

# %%
P= ord("P");
C = P**e % N;
print(C);
# Out:
# 598

# %%
P= ord("I");
C = P**e % N;
print(C);
# Out:
# 480

# %%
P= ord("O");
C = P**e % N;
print(C);
# Out:
# 679
